# %% [markdown]
# # Extracting Survstat data
# This file explains how to download SurvStat data using the current project, through the example of measles. This file will download weekly measles casenumbers from 2001-2025 per Kreis. Based on this data, an aggregated dataset is created that contains weekly measles casenumbers in Germany. These are then plotted as well.

# %%
from update_survstatdata import update_survstat_data
from preview_epicurve import preview_epicurve
from create_sample_data import create_sample_data

# %%
all_years = range(2001,2026)
update_survstat_data(years = [yy for yy in all_years], 
                     diseases_dict = {'Measles': 'measles'}, 
                     method = 'construct')
# Out:
# 🔄 Starting data collection for 1 diseases...
# 📅 Years: [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]
# 🦠 Diseases: ['norovirus']
# Years for norovirus: 100%|██████████| 25/25 [10:17<00:00, 24.72s/it]
# ✅ all data has been scraped
# 🔄 Processing downloaded data...
# processing norovirus: 100%|██████████| 25/25 [00:10<00:00,  2.39it/s]
# ✅ all data has been (pre)processed
# c:\Users\stend\Documents\python_projects\survstat_loader\log.txt
# Last script run: 11 day(s) ago
# 📝 Appending 1 new diseases to existing 20 diseases
# ✅ Data collection and processing completed successfully!

# %%
preview_epicurve('measles')
